# %% [markdown]
# # Neural Network Back Propogation

# %%
# tensorflow is the base open source library and keras is Neural Net library which makes it easy to use
# keras need a backend tensorflow to run the commands
# !pip install tensorflow
# !pip install keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential # generate networks/layers
from keras.layers import Dense # creates layer

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

dataset=np.loadtxt("D:/ExcelR/Data Science(Andheri-Sadanand-Chirag)(21st Aug 2021)/Data Set Files/11.pima-indians-diabetes.csv"
                      ,delimiter=",")
# split data into X and Y variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model/adding layer to model
model = Sequential()  # layers- 8,12,8,1
model.add(Dense(12, input_dim=8, activation="relu"))  #1st hidden layer,input layer
model.add(Dense(8, kernel_initializer="uniform", activation="relu")) #2nd hidden layer
model.add(Dense(1, kernel_initializer="uniform", activation="sigmoid")) #output layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# ...
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#loss=backpropogation calculation method,optimizer=GD variants,metrics=classification table in logistic regression-o/p is binary

# %%
# Fit the model
story=model.fit(X, Y, validation_split=0.33, epochs=350, batch_size=10)
#train->loss-accuracy,test->loss-accuracy
# Out:
# Epoch 1/350
# 52/52 [==============================] - 1s 6ms/step - loss: 0.6914 - accuracy: 0.5525 - val_loss: 0.6639 - val_accuracy: 0.6732
# Epoch 2/350
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6708 - accuracy: 0.6401 - val_loss: 0.6562 - val_accuracy: 0.6732
# Epoch 3/350
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.6401 - val_loss: 0.6542 - val_accuracy: 0.6732
# Epoch 4/350
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.6381 - val_loss: 0.6552 - val_accuracy: 0.6654
# Epoch 5/350
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.6304 - val_loss: 0.6532 - val_accuracy: 0.6654
# Epoch 6/350
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6567 - accuracy: 0.6420 - val_loss: 0.6520 - val_accuracy: 0.6693
# Epoch 7/350
# ...

# %%
story.params
# Out:
# {'verbose': 1, 'epochs': 350, 'steps': 52}

# %% [markdown]
# **%** is a place holder and **f** is for float,**s** is for string.
# This is old print statement formatting.
# print("**% _** " **%** ( **_** )) -> print("**{}**"**.format**( **_** ))
# ,**%s** it will print for string;
# **%f** it will print for float, **%.f** will round off the value to an integer,
# **%.2f**->(2) will work for no. of decimals required by default **%f** will print **6** rounded decimals,
# **%f%%** the last **%%** after f is for printing the %percentage sign.

# %%
# evaluate the model and print its accuracy 
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.7891
# accuracy: 78.91%

# %%
# list all data in history from story as dictionary in key format from keras 
story.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# visualize history for accuracy & loss
fig = plt.figure(figsize=(17,5))
plt.suptitle("Model Accuracy Vs Loss", size=20, y=1.07) 
plt.subplot(1,2,1)
plt.plot(story.history['accuracy'],color="gold")
plt.plot(story.history['val_accuracy'],color="c")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1,2,2)
plt.plot(story.history['loss'],color="gold")
plt.plot(story.history['val_loss'],color="c")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
    print('%s -> %d (expected %d)' % (X[i].tolist(), predictions[i], Y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] -> 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] -> 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] -> 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] -> 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] -> 1 (expected 1)

# %%
#predicting using new data
new_data=pd.DataFrame({'preg':5,"plas":180,"pres":65,"skin":24,"test":0,"mass":24.6,"pedi":0.463,"age":34},index=[1])
print("%.f" % (model.predict(new_data)))
# Out:
# 1
