# %%
#comments

# %% [markdown]
# Jupyter Notebook

# %%
# to check the file saved location ->>

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Satra\\Data Science Self Practise'

# %%
# installing python libraries-!pip is must

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#you need to import liabraries each time you want to use it ->> import __ as __  -as will save it as alias

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#!jupyter contrib nbextension install --user

# %%
# run this in ana

# %%
#to close the output double click below out 
#to make out scroll single click

# %%
# to upload a file ->> filename=pd.read_csv("___.csv")-csv or the extention of file
# the location path should have forward slashes /

# %%
df = pd.read_csv("E:/ExcelR/Data Science(Andheri-Sadanand-Chirag)(21st Aug 2021)/Data Set Files/3.salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# to get the info of the data frame
#->> df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# ### Attributes

# %%
#in data frame-attributes are not defined by parantheses ->> df.___

# %%
#to list the type of columns,to check the data type
#object-string,int64-integer,float64-float

# %%
df["salary"].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns   #to list the name of columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes    # it will list the row labels and column names
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim  # no. of dimensions
# Out:
# 2

# %%
df.size   # no. of elements i.e no. of rows*columns (here it is 78*6)-total cells
# Out:
# 468

# %%
df.shape  #will return tuple of the dimensionality i.e no. of columns and rows
# Out:
# (78, 6)

# %%
df.values  #numpy representation of the data
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [markdown]
# ### Methods

# %%
#in data frame -methods are defined by parantheses ()->> df.__()

# %%
# to view the top & last rows use head and tails by defualt it will show 5 if want more specify it
# df.head()  & df.tail()

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(2)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.count()  #no. of observations in each column ,total no. of records
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
#to find the no. of columns

# %%
df.count().size
# Out:
# 6

# %%
len(df.columns)
# Out:
# 6

# %%
df.describe()   #Descriptive Stats
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()    # for max values
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()   # for min values
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()    # for mean/average
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\1688673369.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()    # for mean/average
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median()    #for median/middle value
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\1456142912.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()    #for median/middle value
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std()    #for std deviation
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\2370392017.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()    #for std deviation
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.sample()   #return random sample data
# Out:
#     rank discipline  phd  service     sex  salary
# 39  Prof          B   18       18  Female  129000

# %%
df.dropna()   #drop all records with missing/NA values i.e NA row
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#to find mean of 50 data frame

# %%
df1=df.head(50)

# %%
df1
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df1.mean()
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.head(50).mean()
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\1648960742.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
# to select a column

# %%
df["salary"]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#to find values for specific columns use chain method
#df.__().column
#df["__"].___()

# %%
df["phd"].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
len(df.phd)
# Out:
# 78

# %%
df.count().phd
# Out:
# 78

# %%
df.describe().phd
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.mean().phd
# Out:
# C:\Users\Satra\AppData\Local\Temp\ipykernel_2652\1296984663.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean().phd
# 19.705128205128204

# %%
#to make data look like a table more presentable add one more braces ->>[[]]

# %%
df[["salary"]]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df[["phd"]].describe()
# Out:
#              phd
# count  78.000000
# mean   19.705128
# std    12.498425
# min     1.000000
# 25%    10.250000
# 50%    18.500000
# 75%    27.750000
# max    56.000000

# %%
#GROUPBY -to split data into groups based on some criteria

# %%
df.groupby(["rank"]).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(["sex"]).std()
# Out:
#               phd    service        salary
# sex
# Female   9.784176   8.813252  25952.127317
# Male    14.138032  13.999711  29110.516397

# %%
df.groupby("sex")[['salary',"phd"]].std()
# Out:
#               salary        phd
# sex
# Female  25952.127317   9.784176
# Male    29110.516397  14.138032

# %%
#Data Filtering  -can give bool values but can find actual data ->> df[df.__<__]

# %%
df.salary<120000
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 73     True
# 74     True
# 75    False
# 76     True
# 77     True
# Name: salary, Length: 78, dtype: bool

# %%
df[df.salary>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#iloc-integer location ->>df.iloc[r:r,c:c]

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[2]       # rows
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           20
# sex             Male
# salary        110515
# Name: 2, dtype: object

# %%
df.iloc[:,2]  #columns
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df.iloc[-1]   #negative is for last -here last row
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[:,-2]  #2nd last column
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[2,3]   #row,column
# Out:
# 20

# %%
df.iloc[:,0:2]  #all rows and 1st-2 columns
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
df.iloc[0:3,0:2]  #1st -3 rows and 1st-2 columns
# Out:
#    rank discipline
# 0  Prof          B
# 1  Prof          A
# 2  Prof          A

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[[0,5],[1,3]] #oth row-1st and 3rd column&5th row-1st and 3rd column
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
#Aggregation Function
#it will compute summary stats for column specified
#->min,max,count,sum,prod,mean,median,mode,mad,std,var,skew.kurt

# %%
df[["phd","salary"]].agg(["mean","std","var","skew","kurt"])
# Out:
#              phd        salary
# mean   19.705128  1.080238e+05
# std    12.498425  2.829366e+04
# var   156.210623  8.005313e+08
# skew    0.634366  4.521026e-01
# kurt    0.042504 -4.017127e-01

# %%
df.sort_values(by="phd").head()  #to sort values as per specified column
# Out:
#         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 60  AsstProf          B    3        3  Female   92000

# %%
df.sort_values(by=["phd","salary"], ascending=[True,True]).head(8)  # for more than one column
# Out:
#         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 57  AsstProf          A    3        1  Female   72500
# 60  AsstProf          B    3        3  Female   92000
# 22  AsstProf          A    4        2    Male   73000
# 68  AsstProf          A    4        2  Female   77500
# 42  AsstProf          B    4        2  Female   80225

# %%
dir(df)   # to list all and methods
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...
